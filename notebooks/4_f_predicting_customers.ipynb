# %%
import pandas as pd
import joblib

# %%
model = joblib.load('../outputs/model/RF/rf_fine_tuned_model.pkl')
df = pd.read_csv('../data/raw/ebi_exp_customers.csv', delimiter=';')

# %%
df
# Out:
#                                                                                                        ebi_exp_customers
# customer_id credit_score country gender age tenure balance   products_number credit_card active_member  estimated_salary
# 15575430    579          France  Female 33  1      118392.75 1               1           1                     157564.75
# 15793890    728          France  Female 59  4      0         1               1           1                     163365.85
# 15701166    660          France  Male   40  5      131754.11 2               1           1                      38761.61
# 15624677    543          Germany Female 37  3      122304.65 2               0           0                       33998.7
# ...                                                                                                                  ...
# 15691624    820          France  Male   33  2      132150.26 2               1           0                      23067.97
# ...

# %%
# safely drop customer_id if it exists (no KeyError if missing)
df.drop(columns=['customer_id'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 2
#       1 # safely drop customer_id if it exists (no KeyError if missing)
# ----> 2 df.drop(columns=['customer_id'], inplace=True)
#
# File ~/Desktop/Git/GitLab/.venv/lib/python3.9/site-packages/pandas/core/frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)
#    5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)
#    5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
# ...

# %%
print(df.columns)
# Out:
# Index(['ebi_exp_customers'], dtype='object')
